# %%
#Задание 1,2
# создаём функцию для вставки 
def insertion_sort(list1): 
        shifts = 0 #Счётчик
        eq = 0  #Счётчик
        # Внешняя петля для прохождения от 1 до len(list1) 
        for i in range(1, len(list1)): 
 
            value = list1[i] 
 
            # Переместить элементы list1[0..i-1], которые
            # больше значения, на одну позицию впереди
            # их текущей позиции
            j = i - 1 
            while j >= 0 and value < list1[j]: 
                eq += 1
                list1[j + 1] = list1[j] 
                j -= 1 
                shifts += 1
                print(list1)
            list1[j + 1] = value   
            shifts += 1
            print(list1)
        return list1,shifts,eq
             
# состояние списка = количеству перестановок.
        
list1 = [7, 3, 9, 4, 2, 5, 6, 1, 8]
print("Неотсортированный список:", list1) 
 
print("Отсортированный список:", insertion_sort(list1))
# Out:
# Неотсортированный список: [7, 3, 9, 4, 2, 5, 6, 1, 8]
# [7, 7, 9, 4, 2, 5, 6, 1, 8]
# [3, 7, 9, 4, 2, 5, 6, 1, 8]
# [3, 7, 9, 4, 2, 5, 6, 1, 8]
# [3, 7, 9, 9, 2, 5, 6, 1, 8]
# [3, 7, 7, 9, 2, 5, 6, 1, 8]
# [3, 4, 7, 9, 2, 5, 6, 1, 8]
# [3, 4, 7, 9, 9, 5, 6, 1, 8]
# [3, 4, 7, 7, 9, 5, 6, 1, 8]
# [3, 4, 4, 7, 9, 5, 6, 1, 8]
# [3, 3, 4, 7, 9, 5, 6, 1, 8]
# [2, 3, 4, 7, 9, 5, 6, 1, 8]
# [2, 3, 4, 7, 9, 9, 6, 1, 8]
# [2, 3, 4, 7, 7, 9, 6, 1, 8]
# [2, 3, 4, 5, 7, 9, 6, 1, 8]
# [2, 3, 4, 5, 7, 9, 9, 1, 8]
# [2, 3, 4, 5, 7, 7, 9, 1, 8]
# [2, 3, 4, 5, 6, 7, 9, 1, 8]
# [2, 3, 4, 5, 6, 7, 9, 9, 8]
# [2, 3, 4, 5, 6, 7, 7, 9, 8]
# [2, 3, 4, 5, 6, 6, 7, 9, 8]
# [2, 3, 4, 5, 5, 6, 7, 9, 8]
# [2, 3, 4, 4, 5, 6, 7, 9, 8]
# [2, 3, 3, 4, 5, 6, 7, 9, 8]
# [2, 2, 3, 4, 5, 6, 7, 9, 8]
# [1, 2, 3, 4, 5, 6, 7, 9, 8]
# [1, 2, 3, 4, 5, 6, 7, 9, 9]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Отсортированный список: ([1, 2, 3, 4, 5, 6, 7, 8, 9], 27, 19)

# %%
#Задание 2
list1 = [3, 5, 2, 9, 8, 1, 6, 4, 7]
print("Неотсортированный список:", list1) 
 
print("Отсортированный список:", insertion_sort(list1))
# Out:
# Неотсортированный список: [3, 5, 2, 9, 8, 1, 6, 4, 7]
# [3, 5, 2, 9, 8, 1, 6, 4, 7]
# [3, 5, 5, 9, 8, 1, 6, 4, 7]
# [3, 3, 5, 9, 8, 1, 6, 4, 7]
# [2, 3, 5, 9, 8, 1, 6, 4, 7]
# [2, 3, 5, 9, 8, 1, 6, 4, 7]
# [2, 3, 5, 9, 9, 1, 6, 4, 7]
# [2, 3, 5, 8, 9, 1, 6, 4, 7]
# [2, 3, 5, 8, 9, 9, 6, 4, 7]
# [2, 3, 5, 8, 8, 9, 6, 4, 7]
# [2, 3, 5, 5, 8, 9, 6, 4, 7]
# [2, 3, 3, 5, 8, 9, 6, 4, 7]
# [2, 2, 3, 5, 8, 9, 6, 4, 7]
# [1, 2, 3, 5, 8, 9, 6, 4, 7]
# [1, 2, 3, 5, 8, 9, 9, 4, 7]
# [1, 2, 3, 5, 8, 8, 9, 4, 7]
# [1, 2, 3, 5, 6, 8, 9, 4, 7]
# [1, 2, 3, 5, 6, 8, 9, 9, 7]
# [1, 2, 3, 5, 6, 8, 8, 9, 7]
# [1, 2, 3, 5, 6, 6, 8, 9, 7]
# [1, 2, 3, 5, 5, 6, 8, 9, 7]
# [1, 2, 3, 4, 5, 6, 8, 9, 7]
# [1, 2, 3, 4, 5, 6, 8, 9, 9]
# [1, 2, 3, 4, 5, 6, 8, 8, 9]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Отсортированный список: ([1, 2, 3, 4, 5, 6, 7, 8, 9], 24, 16)

# %%
#3 Задание
#Сложность алгоритма O(n^2)
#Временная сложность O(n^2)
#Пространственная сложность O(1)
